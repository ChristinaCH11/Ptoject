# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
df = pd.read_csv('bmw1.csv', sep=',')
df
# Out:
#      model  year         price  type  distance  fuel         tax  \
# 0        4  2014  11200.000000     0   67068.0     0  125.000000
# 1       11  2017  18500.000000     2   12160.0     0  145.000000
# 2        2  2017  18300.000000     2   20000.0     0  150.000000
# 3        0  2019  29398.000000     2    9983.0     3  145.000000
# 4        2  2018  22998.000000     2   16360.0     0  145.000000
# ..     ...   ...           ...   ...       ...   ...         ...
# 842      0  2017  13500.000000     1   16423.0     0  150.000000
# 843      0  2016   8800.000000     1   51002.0     0    0.000000
# 844      0  2015  16314.000000     1   17846.0     3  295.328415
# 845      4  2014  15495.000000     2   51565.0     0  160.000000
# 846     15  2019  50647.055451     2    5597.0     0  145.000000
#
#      miles per galoon  size
# 0                57.6   2.0
# 1                65.7   2.0
# 2                62.8   2.0
# 3                39.8   3.0
# 4                57.7   2.0
# ..                ...   ...
# 842              72.4   1.5
# 843              83.1   1.5
# 844              35.3   3.0
# 845              51.4   2.0
# 846              37.7   3.0
#
# [847 rows x 9 columns]

# %%
df['age']=(2021-df['year'])
df
# Out:
#      model  year         price  type  distance  fuel         tax  \
# 0        4  2014  11200.000000     0   67068.0     0  125.000000
# 1       11  2017  18500.000000     2   12160.0     0  145.000000
# 2        2  2017  18300.000000     2   20000.0     0  150.000000
# 3        0  2019  29398.000000     2    9983.0     3  145.000000
# 4        2  2018  22998.000000     2   16360.0     0  145.000000
# ..     ...   ...           ...   ...       ...   ...         ...
# 842      0  2017  13500.000000     1   16423.0     0  150.000000
# 843      0  2016   8800.000000     1   51002.0     0    0.000000
# 844      0  2015  16314.000000     1   17846.0     3  295.328415
# 845      4  2014  15495.000000     2   51565.0     0  160.000000
# 846     15  2019  50647.055451     2    5597.0     0  145.000000
#
#      miles per galoon  size  age
# 0                57.6   2.0    7
# 1                65.7   2.0    4
# 2                62.8   2.0    4
# 3                39.8   3.0    2
# 4                57.7   2.0    3
# ..                ...   ...  ...
# 842              72.4   1.5    4
# 843              83.1   1.5    5
# 844              35.3   3.0    6
# 845              51.4   2.0    7
# 846              37.7   3.0    2
#
# [847 rows x 10 columns]

# %%
df.describe()
# Out:
#             model         year         price        type      distance  \
# count  847.000000   847.000000    847.000000  847.000000    847.000000
# mean     4.318772  2017.055490  21202.038959    1.436836  24695.637662
# std      4.800996     1.707442   9043.637895    0.756665  19827.618230
# min      0.000000  2013.000000   6998.000000    0.000000     10.000000
# 25%      1.000000  2016.000000  14991.000000    1.000000   9007.000000
# 50%      2.000000  2017.000000  19000.000000    2.000000  20001.000000
# 75%      5.500000  2019.000000  24944.000000    2.000000  35618.000000
# max     19.000000  2020.000000  50647.055451    2.000000  84633.016616
#
#              fuel         tax  miles per galoon        size         age
# count  847.000000  847.000000        847.000000  847.000000  847.000000
# mean     0.793388  129.029464         55.626494    2.170956    3.944510
# std      1.307752   55.244498         12.438446    0.509050    1.707442
# min      0.000000    0.000000         31.400000    1.500000    1.000000
# 25%      0.000000  125.000000         48.700000    2.000000    2.000000
# 50%      0.000000  145.000000         54.300000    2.000000    4.000000
# 75%      3.000000  150.000000         62.800000    2.000000    5.000000
# max      3.000000  295.328415        104.084750    3.000000    8.000000

# %%
df['priceLevel']=np.where (df['price']<=21202,0,1)
df
# Out:
#      model  year         price  type  distance  fuel         tax  \
# 0        4  2014  11200.000000     0   67068.0     0  125.000000
# 1       11  2017  18500.000000     2   12160.0     0  145.000000
# 2        2  2017  18300.000000     2   20000.0     0  150.000000
# 3        0  2019  29398.000000     2    9983.0     3  145.000000
# 4        2  2018  22998.000000     2   16360.0     0  145.000000
# ..     ...   ...           ...   ...       ...   ...         ...
# 842      0  2017  13500.000000     1   16423.0     0  150.000000
# 843      0  2016   8800.000000     1   51002.0     0    0.000000
# 844      0  2015  16314.000000     1   17846.0     3  295.328415
# 845      4  2014  15495.000000     2   51565.0     0  160.000000
# 846     15  2019  50647.055451     2    5597.0     0  145.000000
#
#      miles per galoon  size  age  priceLevel
# 0                57.6   2.0    7           0
# 1                65.7   2.0    4           0
# 2                62.8   2.0    4           0
# 3                39.8   3.0    2           1
# 4                57.7   2.0    3           1
# ..                ...   ...  ...         ...
# 842              72.4   1.5    4           0
# 843              83.1   1.5    5           0
# 844              35.3   3.0    6           0
# 845              51.4   2.0    7           0
# 846              37.7   3.0    2           1
#
# [847 rows x 11 columns]

# %%
# Splitting the dataset into the Training set and Test set
a=['model','type','distance','fuel','tax','miles per galoon','size', 'age']
X = df[a]
y = df['priceLevel']
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=13)

# %%
# Feature Scaling
from sklearn.preprocessing import StandardScaler
sc_X = StandardScaler().fit(X_train)
X_train = sc_X.transform(X_train)
X_test = sc_X.transform(X_test)

# %%
#Feature Selection
# Baseline model
import statsmodels.api as sm
lr = sm.Logit(y_train, X_train).fit()
print(lr.summary2())
# Out:
# Optimization terminated successfully.
#          Current function value: 0.304406
#          Iterations 8
#                           Results: Logit
# ==================================================================
# Model:              Logit            Pseudo R-squared: 0.548
# Dependent Variable: priceLevel       AIC:              428.1658
# Date:               2021-12-28 02:20 BIC:              464.3072
# No. Observations:   677              Log-Likelihood:   -206.08
# Df Model:           7                LL-Null:          -455.71
# Df Residuals:       669              LLR p-value:      1.1598e-103
# Converged:          1.0000           Scale:            1.0000
# No. Iterations:     8.0000
# ---------------------------------------------------------------------
#         Coef.     Std.Err.       z       P>|z|      [0.025     0.975]
# ---------------------------------------------------------------------
# x1      1.3876      0.1736     7.9943    0.0000     1.0474     1.7278
# x2      0.2744      0.1255     2.1862    0.0288     0.0284     0.5205
# x3     -1.1050      0.2468    -4.4774    0.0000    -1.5887    -0.6213
# x4      0.0139      0.1560     0.0893    0.9288    -0.2918     0.3197
# x5     -0.4502      0.1962    -2.2954    0.0217    -0.8347    -0.0658
# x6      0.0394      0.1836     0.2147    0.8300    -0.3204     0.3992
# x7      1.6294      0.2070     7.8703    0.0000     1.2236     2.0352
# x8     -2.2964      0.2746    -8.3640    0.0000    -2.8345    -1.7583
# ==================================================================

# %% [markdown]
# Больше всего влияют факторы 1, 3, 7 и 8, а менее всего - 4, 6

# %%
# Automatic Feature Selection
from sklearn.feature_selection import RFECV
from sklearn.linear_model import LogisticRegression
estimator=LogisticRegression(random_state=123)
selector=RFECV(estimator, step=1)
selector=selector.fit(X_train, y_train)
print(selector.n_features_)
print(selector.support_)
print(selector.ranking_)
# Out:
# 5
# [ True False  True False  True False  True  True]
# [1 3 1 4 1 2 1 1]

# %%
#fitting logistic regression
# Leaving only Selected Features
X_train_select=X_train[:,[False, False,  False,  False, False, False, True, True]]
X_test_select=X_test[:,[False, False,  False,  False, False, False, True, True]]

# %%
X_train_select
# Out:
# array([[-1.3032585 ,  0.03696981],
#        [-0.3311276 ,  0.03696981],
#        [-0.3311276 ,  0.6190293 ],
#        ...,
#        [-0.3311276 ,  0.6190293 ],
#        [-0.3311276 , -1.70920867],
#        [ 1.6131342 ,  0.6190293 ]])

# %%
# Fitting Logistic Regression to the Training set 
from sklearn.linear_model import LogisticRegression
lr = LogisticRegression().fit(X_train_select, y_train)

# %%
# Predicting the Test set results
y_pred = lr.predict(X_test_select)
lr.score(X_test_select,y_test).round(3)
# Out:
# 0.894

# %% [markdown]
# Данная модель имеет 10,6% ошибок

# %%
# Making the Confusion Matrix
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, y_pred)
print(cm)
# Out:
# [[94 12]
#  [ 6 58]]

# %% [markdown]
# 162 примеров корректны, 18 - нет

# %%
# Visualising the Test set results
from matplotlib.colors import ListedColormap
X_set, y_set = X_test, y_test
X1, X2 = np.meshgrid(np.arange(start = X_set[:, 0].min() - 1, stop = X_set[:, 0].max() + 1, step = 0.01),
                     np.arange(start = X_set[:, 1].min() - 1, stop = X_set[:, 1].max() + 1, step = 0.01))
plt.contourf(X1, X2, lr.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha = 0.75, cmap = ListedColormap(('red', 'green')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c = ListedColormap(('red', 'green'))(i), label = j)
plt.title('Logistic Regression (Test set)')
plt.xlabel('age')
plt.ylabel('size')
plt.legend()
plt.show()
# Out:
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.
# *c* argument looks like a single numeric RGB or RGBA sequence, which should be avoided as value-mapping will have precedence in case its length matches with *x* & *y*.  Please use the *color* keyword-argument or provide a 2-D array with a single row if you intend to specify the same RGB or RGBA value for all points.

# %%
import pickle
obj = {'X_train': X_train_select, 'X_test': X_test_select,'y_train': y_train,'y_test': y_test}
output = open('bmw4.pkl', 'wb')
pickle.dump(obj, output, 2)
output.close()
